# %%
# Import the dependencies.

import pandas as pd

import matplotlib.pyplot as plt

import numpy as np

from citipy import citipy

import requests

import time

from config import weather_api_key

from datetime import datetime

from scipy.stats import linregress

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list.

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 786

# %%
# Create an empty list to hold the weather data.

city_data = []

# Print the beginning of the logging.

print("Beginning Data Retrieval     ")

print("-----------------------------")

# Create counters.

record_count = 1

set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)

    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
# Run an API request for each of the cities.

    try:
        
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["main"]
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          
                          "Country": city_country,
                          
                          "Lat": city_lat,
                          
                          "Lng": city_lng,
                          
                          "Max Temp": city_max_temp,
                          
                          "Humidity": city_humidity,
                          
                          "Cloudiness": city_clouds,
                          
                          "Wind Speed": city_wind,
                          
                          "Current Description": city_description})

# If an error is experienced, skip the city.

    except:
        
        print("City not found. Skipping...")
        
        pass
        

# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | robertsport
# Processing Record 2 of Set 1 | lavrentiya
# Processing Record 3 of Set 1 | hambantota
# Processing Record 4 of Set 1 | harrismith
# Processing Record 5 of Set 1 | northam
# Processing Record 6 of Set 1 | zhuhai
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | anadyr
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | zhangjiakou
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | masuda
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | ust-kan
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | kemijarvi
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | concord
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | forecariah
# Processing Record 26 of Set 1 | banos
# Processing Record 27 of Set 1 | seymchan
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | tsabong
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | tsybli
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | gorzow wielkopolski
# Processing Record 38 of Set 1 | bali
# Processing Record 39 of Set 1 | camana
# Processing Record 40 of Set 1 | moa
# Processing Record 41 of Set 1 | san quintin
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | port hedland
# Processing Record 44 of Set 1 | verkhnyaya inta
# Processing Record 45 of Set 1 | harnosand
# Processing Record 46 of Set 1 | cherskiy
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | ken caryl
# Processing Record 49 of Set 1 | chilca
# Processing Record 50 of Set 1 | kushmurun
# Processing Record 1 of Set 2 | buala
# Processing Record 2 of Set 2 | idah
# Processing Record 3 of Set 2 | misratah
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | hachinohe
# Processing Record 8 of Set 2 | xai-xai
# Processing Record 9 of Set 2 | baixa grande
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | rosetta
# Processing Record 13 of Set 2 | naliya
# Processing Record 14 of Set 2 | opuwo
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | belen
# Processing Record 17 of Set 2 | hilo
# Processing Record 18 of Set 2 | vostok
# Processing Record 19 of Set 2 | kosice
# Processing Record 20 of Set 2 | nalut
# Processing Record 21 of Set 2 | la ronge
# Processing Record 22 of Set 2 | nizhniy tsasuchey
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | roma
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | marzuq
# Processing Record 31 of Set 2 | rikitea
# Processing Record 32 of Set 2 | dunedin
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | adrar
# Processing Record 40 of Set 2 | srandakan
# Processing Record 41 of Set 2 | gambela
# Processing Record 42 of Set 2 | port lincoln
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | copiapo
# Processing Record 45 of Set 2 | karasjok
# Processing Record 46 of Set 2 | poopo
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | poum
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | novosergiyevka
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | paka
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | batagay-alyta
# Processing Record 6 of Set 3 | griffith
# Processing Record 7 of Set 3 | rawson
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | fairbanks
# Processing Record 10 of Set 3 | karasuk
# Processing Record 11 of Set 3 | kolpashevo
# Processing Record 12 of Set 3 | ajdabiya
# Processing Record 13 of Set 3 | busselton
# Processing Record 14 of Set 3 | auki
# Processing Record 15 of Set 3 | nanortalik
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | kandi
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | glyadyanskoye
# Processing Record 23 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 3 | umm kaddadah
# Processing Record 25 of Set 3 | bluff
# Processing Record 26 of Set 3 | linguere
# Processing Record 27 of Set 3 | avera
# Processing Record 28 of Set 3 | byron bay
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | bukama
# Processing Record 31 of Set 3 | jaggayyapeta
# Processing Record 32 of Set 3 | srednekolymsk
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | esperance
# Processing Record 35 of Set 3 | chernyshevskiy
# Processing Record 36 of Set 3 | kaoma
# Processing Record 37 of Set 3 | qixia
# Processing Record 38 of Set 3 | katsuura
# Processing Record 39 of Set 3 | taoudenni
# Processing Record 40 of Set 3 | ilulissat
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | avigliana
# Processing Record 43 of Set 3 | awjilah
# Processing Record 44 of Set 3 | troitskoye
# Processing Record 45 of Set 3 | puerto ayora
# Processing Record 46 of Set 3 | asau
# Processing Record 47 of Set 3 | praxedis guerrero
# Processing Record 48 of Set 3 | tasiilaq
# Processing Record 49 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 3 | bethel
# Processing Record 1 of Set 4 | ugoofaaru
# Processing Record 2 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | savannah bight
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | matagami
# Processing Record 8 of Set 4 | luena
# Processing Record 9 of Set 4 | coahuayana
# Processing Record 10 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 4 | abu samrah
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | gunnedah
# Processing Record 15 of Set 4 | westport
# Processing Record 16 of Set 4 | hukuntsi
# Processing Record 17 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 4 | barra patuca
# Processing Record 19 of Set 4 | presidencia roque saenz pena
# Processing Record 20 of Set 4 | yago
# Processing Record 21 of Set 4 | ossora
# Processing Record 22 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 4 | muzhi
# Processing Record 24 of Set 4 | coronado
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | vila
# Processing Record 27 of Set 4 | honningsvag
# Processing Record 28 of Set 4 | azoyu
# Processing Record 29 of Set 4 | romitan
# Processing Record 30 of Set 4 | portland
# Processing Record 31 of Set 4 | dong hoi
# Processing Record 32 of Set 4 | athabasca
# Processing Record 33 of Set 4 | osa
# Processing Record 34 of Set 4 | tenenkou
# Processing Record 35 of Set 4 | muros
# Processing Record 36 of Set 4 | kieta
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | dubenskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | college
# Processing Record 40 of Set 4 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | qaanaaq
# Processing Record 43 of Set 4 | san policarpo
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | prince rupert
# Processing Record 47 of Set 4 | nome
# Processing Record 48 of Set 4 | talnakh
# Processing Record 49 of Set 4 | cururupu
# Processing Record 50 of Set 4 | port alfred
# Processing Record 1 of Set 5 | danilov
# Processing Record 2 of Set 5 | chapulhuacan
# Processing Record 3 of Set 5 | raduzhnyy
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | port-gentil
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | ambon
# Processing Record 9 of Set 5 | cabral
# Processing Record 10 of Set 5 | manzil jamil
# City not found. Skipping...
# Processing Record 11 of Set 5 | novoorsk
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | lebu
# Processing Record 14 of Set 5 | port hardy
# Processing Record 15 of Set 5 | tuatapere
# Processing Record 16 of Set 5 | garden city
# Processing Record 17 of Set 5 | marshall
# Processing Record 18 of Set 5 | port blair
# Processing Record 19 of Set 5 | jose bonifacio
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | hervey bay
# Processing Record 22 of Set 5 | lons-le-saunier
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | ndjole
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | kitob
# Processing Record 27 of Set 5 | clinton
# Processing Record 28 of Set 5 | airai
# Processing Record 29 of Set 5 | souillac
# Processing Record 30 of Set 5 | coihueco
# Processing Record 31 of Set 5 | ratesti
# Processing Record 32 of Set 5 | yatou
# Processing Record 33 of Set 5 | sinnamary
# Processing Record 34 of Set 5 | kenai
# Processing Record 35 of Set 5 | cidreira
# Processing Record 36 of Set 5 | kavieng
# Processing Record 37 of Set 5 | grand gaube
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 40 of Set 5 | trat
# Processing Record 41 of Set 5 | yiyang
# Processing Record 42 of Set 5 | janow lubelski
# Processing Record 43 of Set 5 | harper
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | shache
# Processing Record 46 of Set 5 | barberton
# Processing Record 47 of Set 5 | gerash
# Processing Record 48 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 5 | pouebo
# Processing Record 50 of Set 5 | ancud
# Processing Record 1 of Set 6 | rosarito
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | hami
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | te anau
# Processing Record 6 of Set 6 | salalah
# Processing Record 7 of Set 6 | itarema
# Processing Record 8 of Set 6 | hobart
# Processing Record 9 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 6 | ocala
# Processing Record 11 of Set 6 | valera
# Processing Record 12 of Set 6 | ribeira grande
# Processing Record 13 of Set 6 | techiman
# Processing Record 14 of Set 6 | anqing
# Processing Record 15 of Set 6 | bilibino
# Processing Record 16 of Set 6 | boyolangu
# Processing Record 17 of Set 6 | fortuna
# Processing Record 18 of Set 6 | a
# City not found. Skipping...
# Processing Record 19 of Set 6 | aklavik
# Processing Record 20 of Set 6 | piacabucu
# Processing Record 21 of Set 6 | bardiyah
# Processing Record 22 of Set 6 | leshan
# Processing Record 23 of Set 6 | ola
# Processing Record 24 of Set 6 | mahajanga
# Processing Record 25 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 6 | pingzhuang
# Processing Record 27 of Set 6 | itanhem
# Processing Record 28 of Set 6 | tautira
# Processing Record 29 of Set 6 | toyooka
# Processing Record 30 of Set 6 | yining
# Processing Record 31 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 32 of Set 6 | concepcion del uruguay
# Processing Record 33 of Set 6 | chuy
# Processing Record 34 of Set 6 | moctezuma
# Processing Record 35 of Set 6 | buritizeiro
# Processing Record 36 of Set 6 | kindia
# Processing Record 37 of Set 6 | male
# Processing Record 38 of Set 6 | isangel
# Processing Record 39 of Set 6 | khandyga
# Processing Record 40 of Set 6 | krasnoselkup
# Processing Record 41 of Set 6 | severo-kurilsk
# Processing Record 42 of Set 6 | catalao
# Processing Record 43 of Set 6 | nemuro
# Processing Record 44 of Set 6 | pangai
# Processing Record 45 of Set 6 | benjamin aceval
# Processing Record 46 of Set 6 | bambous virieux
# Processing Record 47 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 6 | weligama
# Processing Record 49 of Set 6 | oussouye
# Processing Record 50 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | tukrah
# Processing Record 4 of Set 7 | boquira
# Processing Record 5 of Set 7 | banjar
# Processing Record 6 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 7 | pangnirtung
# Processing Record 8 of Set 7 | bonthe
# Processing Record 9 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 10 of Set 7 | katobu
# Processing Record 11 of Set 7 | kimbe
# Processing Record 12 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 7 | basoko
# Processing Record 14 of Set 7 | lorengau
# Processing Record 15 of Set 7 | alekseyevsk
# Processing Record 16 of Set 7 | derazhnya
# Processing Record 17 of Set 7 | puerto morazan
# Processing Record 18 of Set 7 | darbhanga
# Processing Record 19 of Set 7 | abu zabad
# Processing Record 20 of Set 7 | sarankhola
# Processing Record 21 of Set 7 | namtsy
# Processing Record 22 of Set 7 | kirakira
# Processing Record 23 of Set 7 | amli
# Processing Record 24 of Set 7 | touros
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | fare
# Processing Record 27 of Set 7 | lagoa
# Processing Record 28 of Set 7 | richardson
# Processing Record 29 of Set 7 | port augusta
# Processing Record 30 of Set 7 | cabo san lucas
# Processing Record 31 of Set 7 | puerto carreno
# Processing Record 32 of Set 7 | yermakovskoye
# Processing Record 33 of Set 7 | hobyo
# Processing Record 34 of Set 7 | porto novo
# Processing Record 35 of Set 7 | atambua
# Processing Record 36 of Set 7 | korla
# Processing Record 37 of Set 7 | asfi
# Processing Record 38 of Set 7 | ostrovnoy
# Processing Record 39 of Set 7 | iztapa
# Processing Record 40 of Set 7 | najran
# Processing Record 41 of Set 7 | olafsvik
# Processing Record 42 of Set 7 | ahja
# Processing Record 43 of Set 7 | santa vitoria
# Processing Record 44 of Set 7 | gawler
# Processing Record 45 of Set 7 | siavonga
# Processing Record 46 of Set 7 | egvekinot
# Processing Record 47 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 48 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 7 | lovozero
# Processing Record 50 of Set 7 | togur
# Processing Record 1 of Set 8 | roebourne
# Processing Record 2 of Set 8 | bereda
# Processing Record 3 of Set 8 | kajaani
# Processing Record 4 of Set 8 | luganville
# Processing Record 5 of Set 8 | svetlogorsk
# Processing Record 6 of Set 8 | mayumba
# Processing Record 7 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 8 | carutapera
# Processing Record 9 of Set 8 | baykit
# Processing Record 10 of Set 8 | takoradi
# Processing Record 11 of Set 8 | rocha
# Processing Record 12 of Set 8 | guerrero negro
# Processing Record 13 of Set 8 | derzhavinsk
# Processing Record 14 of Set 8 | corn island
# Processing Record 15 of Set 8 | boa vista
# Processing Record 16 of Set 8 | komsomolskiy
# Processing Record 17 of Set 8 | isiro
# Processing Record 18 of Set 8 | drayton valley
# Processing Record 19 of Set 8 | broken hill
# Processing Record 20 of Set 8 | normandin
# Processing Record 21 of Set 8 | aguimes
# Processing Record 22 of Set 8 | yima
# Processing Record 23 of Set 8 | vardo
# Processing Record 24 of Set 8 | zonguldak
# Processing Record 25 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 8 | komsomolskoye
# Processing Record 27 of Set 8 | dalvik
# Processing Record 28 of Set 8 | bahia honda
# Processing Record 29 of Set 8 | rio grande
# Processing Record 30 of Set 8 | ucluelet
# Processing Record 31 of Set 8 | viedma
# Processing Record 32 of Set 8 | qasigiannguit
# Processing Record 33 of Set 8 | krasnoarmeysk
# Processing Record 34 of Set 8 | port keats
# Processing Record 35 of Set 8 | nuuk
# Processing Record 36 of Set 8 | ulladulla
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 8 | iqaluit
# Processing Record 40 of Set 8 | clyde river
# Processing Record 41 of Set 8 | juwana
# Processing Record 42 of Set 8 | lamar
# Processing Record 43 of Set 8 | boca do acre
# Processing Record 44 of Set 8 | charters towers
# Processing Record 45 of Set 8 | zuwarah
# Processing Record 46 of Set 8 | bandarbeyla
# Processing Record 47 of Set 8 | marsabit
# Processing Record 48 of Set 8 | shakhrinau
# City not found. Skipping...
# Processing Record 49 of Set 8 | cozumel
# Processing Record 50 of Set 8 | leeton
# Processing Record 1 of Set 9 | nenjiang
# Processing Record 2 of Set 9 | port-de-bouc
# Processing Record 3 of Set 9 | faanui
# Processing Record 4 of Set 9 | sobolevo
# Processing Record 5 of Set 9 | san patricio
# Processing Record 6 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 9 | iranshahr
# Processing Record 8 of Set 9 | kilindoni
# Processing Record 9 of Set 9 | tilichiki
# Processing Record 10 of Set 9 | sambava
# Processing Record 11 of Set 9 | tahta
# Processing Record 12 of Set 9 | paamiut
# Processing Record 13 of Set 9 | maniwaki
# Processing Record 14 of Set 9 | yulara
# Processing Record 15 of Set 9 | cocentaina
# Processing Record 16 of Set 9 | taft
# Processing Record 17 of Set 9 | masvingo
# Processing Record 18 of Set 9 | chicama
# Processing Record 19 of Set 9 | khorixas
# Processing Record 20 of Set 9 | sur
# Processing Record 21 of Set 9 | slave lake
# Processing Record 22 of Set 9 | gizo
# Processing Record 23 of Set 9 | baiao
# Processing Record 24 of Set 9 | birao
# Processing Record 25 of Set 9 | catanduva
# Processing Record 26 of Set 9 | santa marta
# Processing Record 27 of Set 9 | labuhan
# Processing Record 28 of Set 9 | bontang
# Processing Record 29 of Set 9 | jinchang
# Processing Record 30 of Set 9 | omsukchan
# Processing Record 31 of Set 9 | kalmunai
# Processing Record 32 of Set 9 | kakrala
# Processing Record 33 of Set 9 | nuevo laredo
# Processing Record 34 of Set 9 | teya
# Processing Record 35 of Set 9 | wanning
# Processing Record 36 of Set 9 | naantali
# Processing Record 37 of Set 9 | privolzhye
# Processing Record 38 of Set 9 | praia
# Processing Record 39 of Set 9 | urla
# Processing Record 40 of Set 9 | leningradskiy
# Processing Record 41 of Set 9 | krasnyy chikoy
# Processing Record 42 of Set 9 | kankon
# Processing Record 43 of Set 9 | tazmalt
# Processing Record 44 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 45 of Set 9 | comodoro rivadavia
# Processing Record 46 of Set 9 | beringovskiy
# Processing Record 47 of Set 9 | santa cruz de tenerife
# Processing Record 48 of Set 9 | konevo
# Processing Record 49 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 9 | richards bay
# Processing Record 1 of Set 10 | biltine
# Processing Record 2 of Set 10 | leshukonskoye
# Processing Record 3 of Set 10 | canutama
# Processing Record 4 of Set 10 | bandipur
# Processing Record 5 of Set 10 | labuan
# Processing Record 6 of Set 10 | jizan
# Processing Record 7 of Set 10 | kazachinskoye
# Processing Record 8 of Set 10 | bende
# Processing Record 9 of Set 10 | traiguen
# Processing Record 10 of Set 10 | parakou
# Processing Record 11 of Set 10 | silopi
# Processing Record 12 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | milkovo
# Processing Record 15 of Set 10 | trelew
# Processing Record 16 of Set 10 | virginia
# Processing Record 17 of Set 10 | burica
# City not found. Skipping...
# Processing Record 18 of Set 10 | benicarlo
# Processing Record 19 of Set 10 | nouadhibou
# Processing Record 20 of Set 10 | la grande
# Processing Record 21 of Set 10 | vila velha
# Processing Record 22 of Set 10 | guarapari
# Processing Record 23 of Set 10 | mecca
# Processing Record 24 of Set 10 | omboue
# Processing Record 25 of Set 10 | strenci
# Processing Record 26 of Set 10 | palafrugell
# Processing Record 27 of Set 10 | kyren
# Processing Record 28 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 10 | cap malheureux
# Processing Record 30 of Set 10 | praia da vitoria
# Processing Record 31 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 10 | khasan
# Processing Record 33 of Set 10 | naples
# Processing Record 34 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 10 | namatanai
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | tabou
# Processing Record 38 of Set 10 | cabo rojo
# Processing Record 39 of Set 10 | chapais
# Processing Record 40 of Set 10 | cestas
# Processing Record 41 of Set 10 | saint-pierre
# Processing Record 42 of Set 10 | tura
# Processing Record 43 of Set 10 | carballo
# Processing Record 44 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 45 of Set 10 | rio tinto
# Processing Record 46 of Set 10 | ostersund
# Processing Record 47 of Set 10 | sola
# Processing Record 48 of Set 10 | haimen
# Processing Record 49 of Set 10 | methoni
# Processing Record 50 of Set 10 | katiola
# Processing Record 1 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 11 | mirina
# City not found. Skipping...
# Processing Record 3 of Set 11 | winnemucca
# Processing Record 4 of Set 11 | urubicha
# Processing Record 5 of Set 11 | kapuskasing
# Processing Record 6 of Set 11 | nizwa
# Processing Record 7 of Set 11 | bowen
# Processing Record 8 of Set 11 | sao gabriel
# Processing Record 9 of Set 11 | dingle
# Processing Record 10 of Set 11 | mana
# Processing Record 11 of Set 11 | galchino
# City not found. Skipping...
# Processing Record 12 of Set 11 | anito
# Processing Record 13 of Set 11 | constitucion
# Processing Record 14 of Set 11 | ushtobe
# Processing Record 15 of Set 11 | hunterville
# Processing Record 16 of Set 11 | honiara
# Processing Record 17 of Set 11 | luderitz
# Processing Record 18 of Set 11 | san andres
# Processing Record 19 of Set 11 | atar
# Processing Record 20 of Set 11 | preston
# Processing Record 21 of Set 11 | vanavara
# Processing Record 22 of Set 11 | walvis bay
# Processing Record 23 of Set 11 | amahai
# Processing Record 24 of Set 11 | pedasi
# Processing Record 25 of Set 11 | eenhana
# Processing Record 26 of Set 11 | pisco
# Processing Record 27 of Set 11 | moss vale
# Processing Record 28 of Set 11 | port macquarie
# Processing Record 29 of Set 11 | timbiqui
# Processing Record 30 of Set 11 | darhan
# Processing Record 31 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 32 of Set 11 | nyurba
# Processing Record 33 of Set 11 | general pico
# Processing Record 34 of Set 11 | sperkhias
# City not found. Skipping...
# Processing Record 35 of Set 11 | acoua
# Processing Record 36 of Set 11 | ullapool
# Processing Record 37 of Set 11 | itaobim
# Processing Record 38 of Set 11 | sergeyevka
# Processing Record 39 of Set 11 | mahibadhoo
# Processing Record 40 of Set 11 | ayios matthaios
# City not found. Skipping...
# Processing Record 41 of Set 11 | paragominas
# Processing Record 42 of Set 11 | zhigansk
# Processing Record 43 of Set 11 | monticello
# Processing Record 44 of Set 11 | inirida
# Processing Record 45 of Set 11 | tambulan
# City not found. Skipping...
# Processing Record 46 of Set 11 | joshimath
# Processing Record 47 of Set 11 | samarai
# Processing Record 48 of Set 11 | tazovskiy
# Processing Record 49 of Set 11 | dakar
# Processing Record 50 of Set 11 | baruun-urt
# Processing Record 1 of Set 12 | ornskoldsvik
# Processing Record 2 of Set 12 | hegang
# Processing Record 3 of Set 12 | yenagoa
# Processing Record 4 of Set 12 | kavaratti
# Processing Record 5 of Set 12 | mawlamyine
# Processing Record 6 of Set 12 | biloela
# Processing Record 7 of Set 12 | brae
# Processing Record 8 of Set 12 | kirensk
# Processing Record 9 of Set 12 | kovdor
# Processing Record 10 of Set 12 | general roca
# Processing Record 11 of Set 12 | umm lajj
# Processing Record 12 of Set 12 | moron
# Processing Record 13 of Set 12 | puerto del rosario
# Processing Record 14 of Set 12 | colesberg
# Processing Record 15 of Set 12 | medea
# Processing Record 16 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 12 | inta
# Processing Record 18 of Set 12 | lazaro cardenas
# Processing Record 19 of Set 12 | chulman
# Processing Record 20 of Set 12 | villamontes
# Processing Record 21 of Set 12 | boshnyakovo
# Processing Record 22 of Set 12 | ayan
# Processing Record 23 of Set 12 | bojnurd
# Processing Record 24 of Set 12 | tauteu
# Processing Record 25 of Set 12 | solnechnyy
# Processing Record 26 of Set 12 | chandur
# Processing Record 27 of Set 12 | pak phanang
# Processing Record 28 of Set 12 | nishihara
# Processing Record 29 of Set 12 | muisne
# Processing Record 30 of Set 12 | igrim
# Processing Record 31 of Set 12 | portmore
# Processing Record 32 of Set 12 | lahaina
# Processing Record 33 of Set 12 | koster
# Processing Record 34 of Set 12 | areosa
# Processing Record 35 of Set 12 | pitkyaranta
# Processing Record 36 of Set 12 | margate
# Processing Record 37 of Set 12 | bredy
# Processing Record 38 of Set 12 | coihaique
# Processing Record 39 of Set 12 | necochea
# Processing Record 40 of Set 12 | kiunga
# Processing Record 41 of Set 12 | sao felix do xingu
# Processing Record 42 of Set 12 | antalya
# Processing Record 43 of Set 12 | husavik
# Processing Record 44 of Set 12 | plettenberg bay
# Processing Record 45 of Set 12 | shirokiy
# Processing Record 46 of Set 12 | troitsko-pechorsk
# Processing Record 47 of Set 12 | ionia
# Processing Record 48 of Set 12 | balkanabat
# Processing Record 49 of Set 12 | calama
# Processing Record 50 of Set 12 | keuruu
# Processing Record 1 of Set 13 | lata
# Processing Record 2 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 13 | nykoping
# Processing Record 4 of Set 13 | fort nelson
# Processing Record 5 of Set 13 | conway
# Processing Record 6 of Set 13 | yumen
# Processing Record 7 of Set 13 | butterworth
# Processing Record 8 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 9 of Set 13 | pacific grove
# Processing Record 10 of Set 13 | kununurra
# Processing Record 11 of Set 13 | juneau
# Processing Record 12 of Set 13 | porto velho
# Processing Record 13 of Set 13 | shubarkuduk
# Processing Record 14 of Set 13 | nassau
# Processing Record 15 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 13 | valparaiso
# Processing Record 17 of Set 13 | erenhot
# Processing Record 18 of Set 13 | kodinsk
# Processing Record 19 of Set 13 | malko tarnovo
# Processing Record 20 of Set 13 | antofagasta
# Processing Record 21 of Set 13 | great yarmouth
# Processing Record 22 of Set 13 | rozhyshche
# Processing Record 23 of Set 13 | kedrovyy
# Processing Record 24 of Set 13 | uige
# Processing Record 25 of Set 13 | santa cruz
# Processing Record 26 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 13 | bodaybo
# Processing Record 28 of Set 13 | madimba
# Processing Record 29 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 13 | chivilcoy
# Processing Record 31 of Set 13 | ust-kachka
# Processing Record 32 of Set 13 | nanakuli
# Processing Record 33 of Set 13 | berlevag
# Processing Record 34 of Set 13 | guaymas
# Processing Record 35 of Set 13 | guiratinga
# Processing Record 36 of Set 13 | krutikha
# Processing Record 37 of Set 13 | catuday
# Processing Record 38 of Set 13 | pahrump
# Processing Record 39 of Set 13 | tual
# Processing Record 40 of Set 13 | synya
# Processing Record 41 of Set 13 | nelson bay
# Processing Record 42 of Set 13 | ca mau
# Processing Record 43 of Set 13 | saint-joseph
# Processing Record 44 of Set 13 | melur
# Processing Record 45 of Set 13 | cubuk
# Processing Record 46 of Set 13 | fairlie
# Processing Record 47 of Set 13 | nzega
# Processing Record 48 of Set 13 | teguldet
# Processing Record 49 of Set 13 | mattru
# Processing Record 50 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 1 of Set 14 | belmonte
# Processing Record 2 of Set 14 | ulyanovo
# City not found. Skipping...
# Processing Record 3 of Set 14 | sarata
# Processing Record 4 of Set 14 | parana
# Processing Record 5 of Set 14 | dubai
# Processing Record 6 of Set 14 | ukiah
# Processing Record 7 of Set 14 | skjervoy
# Processing Record 8 of Set 14 | mildura
# Processing Record 9 of Set 14 | olinda
# Processing Record 10 of Set 14 | afmadu
# City not found. Skipping...
# Processing Record 11 of Set 14 | san diego de la union
# Processing Record 12 of Set 14 | alta floresta
# Processing Record 13 of Set 14 | los llanos de aridane
# Processing Record 14 of Set 14 | trincomalee
# Processing Record 15 of Set 14 | luanda
# Processing Record 16 of Set 14 | akureyri
# Processing Record 17 of Set 14 | grindavik
# Processing Record 18 of Set 14 | ho
# City not found. Skipping...
# Processing Record 19 of Set 14 | mendi
# Processing Record 20 of Set 14 | tadine
# Processing Record 21 of Set 14 | ayolas
# Processing Record 22 of Set 14 | shimoda
# Processing Record 23 of Set 14 | kupang
# Processing Record 24 of Set 14 | kota belud
# Processing Record 25 of Set 14 | vila franca do campo
# Processing Record 26 of Set 14 | diebougou
# Processing Record 27 of Set 14 | kjollefjord
# Processing Record 28 of Set 14 | kyra
# Processing Record 29 of Set 14 | naica
# Processing Record 30 of Set 14 | swellendam
# Processing Record 31 of Set 14 | sisimiut
# Processing Record 32 of Set 14 | tooele
# Processing Record 33 of Set 14 | laguna
# Processing Record 34 of Set 14 | rameswaram
# Processing Record 35 of Set 14 | arman
# Processing Record 36 of Set 14 | yuli
# Processing Record 37 of Set 14 | san francisco
# Processing Record 38 of Set 14 | sechura
# Processing Record 39 of Set 14 | azuaga
# Processing Record 40 of Set 14 | quatre cocos
# Processing Record 41 of Set 14 | sjenica
# Processing Record 42 of Set 14 | aasiaat
# Processing Record 43 of Set 14 | puerto rico
# Processing Record 44 of Set 14 | santa maria
# Processing Record 45 of Set 14 | caravelas
# Processing Record 46 of Set 14 | rio gallegos
# Processing Record 47 of Set 14 | kalisz
# Processing Record 48 of Set 14 | malaryta
# Processing Record 49 of Set 14 | freetown
# Processing Record 50 of Set 14 | sar-e pul
# Processing Record 1 of Set 15 | kampot
# Processing Record 2 of Set 15 | bubaque
# Processing Record 3 of Set 15 | saint-augustin
# Processing Record 4 of Set 15 | gondar
# Processing Record 5 of Set 15 | carndonagh
# Processing Record 6 of Set 15 | tongzi
# Processing Record 7 of Set 15 | pochutla
# Processing Record 8 of Set 15 | turayf
# Processing Record 9 of Set 15 | bireun
# Processing Record 10 of Set 15 | mansehra
# Processing Record 11 of Set 15 | banes
# Processing Record 12 of Set 15 | caetite
# Processing Record 13 of Set 15 | victor harbor
# Processing Record 14 of Set 15 | ballina
# Processing Record 15 of Set 15 | padang
# Processing Record 16 of Set 15 | shuiji
# Processing Record 17 of Set 15 | truth or consequences
# Processing Record 18 of Set 15 | havelock
# Processing Record 19 of Set 15 | alexandria
# Processing Record 20 of Set 15 | almora
# Processing Record 21 of Set 15 | thinadhoo
# Processing Record 22 of Set 15 | urucara
# Processing Record 23 of Set 15 | mehamn
# Processing Record 24 of Set 15 | iguatemi
# Processing Record 25 of Set 15 | leua
# Processing Record 26 of Set 15 | mimoso do sul
# Processing Record 27 of Set 15 | woodward
# Processing Record 28 of Set 15 | yamada
# Processing Record 29 of Set 15 | innisfail
# Processing Record 30 of Set 15 | corbita
# Processing Record 31 of Set 15 | elko
# Processing Record 32 of Set 15 | puerto escondido
# Processing Record 33 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 15 | camiri
# Processing Record 35 of Set 15 | la rioja
# Processing Record 36 of Set 15 | rock sound
# Processing Record 37 of Set 15 | yueyang
# Processing Record 38 of Set 15 | mkushi
# Processing Record 39 of Set 15 | lora del rio
# Processing Record 40 of Set 15 | half moon bay
# Processing Record 41 of Set 15 | havre-saint-pierre
# Processing Record 42 of Set 15 | nangong
# Processing Record 43 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 15 | sao raimundo das mangabeiras
# Processing Record 45 of Set 15 | pijao
# Processing Record 46 of Set 15 | puerto pinasco
# City not found. Skipping...
# Processing Record 47 of Set 15 | kpandae
# Processing Record 48 of Set 15 | nioro
# Processing Record 49 of Set 15 | chavakkad
# Processing Record 50 of Set 15 | mitu
# Processing Record 1 of Set 16 | liminangcong
# City not found. Skipping...
# Processing Record 2 of Set 16 | jumla
# Processing Record 3 of Set 16 | sistranda
# Processing Record 4 of Set 16 | kropotkin
# Processing Record 5 of Set 16 | canico
# Processing Record 6 of Set 16 | tromso
# Processing Record 7 of Set 16 | kabanjahe
# Processing Record 8 of Set 16 | hay river
# Processing Record 9 of Set 16 | bend
# Processing Record 10 of Set 16 | mabaruma
# Processing Record 11 of Set 16 | kautokeino
# Processing Record 12 of Set 16 | wundanyi
# Processing Record 13 of Set 16 | maldonado
# Processing Record 14 of Set 16 | abu kamal
# Processing Record 15 of Set 16 | vao
# Processing Record 16 of Set 16 | ratnagiri
# Processing Record 17 of Set 16 | bonavista
# Processing Record 18 of Set 16 | santa rosa
# Processing Record 19 of Set 16 | moose factory
# Processing Record 20 of Set 16 | menongue
# Processing Record 21 of Set 16 | meulaboh
# Processing Record 22 of Set 16 | rennes
# Processing Record 23 of Set 16 | candawaga
# City not found. Skipping...
# Processing Record 24 of Set 16 | renfrew
# Processing Record 25 of Set 16 | klaksvik
# Processing Record 26 of Set 16 | khuzhir
# Processing Record 27 of Set 16 | barro
# Processing Record 28 of Set 16 | sioux lookout
# Processing Record 29 of Set 16 | salinas
# Processing Record 30 of Set 16 | bilma
# Processing Record 31 of Set 16 | lincoln
# Processing Record 32 of Set 16 | ashland
# Processing Record 33 of Set 16 | narasaraopet
# Processing Record 34 of Set 16 | louisville
# Processing Record 35 of Set 16 | khujner
# Processing Record 36 of Set 16 | suao
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 719

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16800/3726938658.py in <module>
#       1 # Convert the array of dictionaries to a Pandas DataFrame.
#       2
# ----> 3 city_data_df = pd.DataFrame(city_data)
#       4
#       5 city_data_df.head(10)
#
# NameError: name 'pd' is not defined

# %%
# Export the City_Data into a CSV.

city_data_df.to_csv('WeatherPy_Database.csv', index_label="City_ID")
